# %% [markdown]
# **Recopilación y muestra de datos**

# %%
nombre = input( "ingrese su nombre:" )
print(f"!Hola {nombre}¡")
# Out:
# ingrese su nombre:Leandro
# !Hola Leandro¡

# %%
nombre = input('ingrese su nombre: ')
edad = input('ingrese su edad: ')
print(f'!Hola {nombre}¡, tienes {edad} años.')
# Out:
# ingrese su nombre: Leandro
# ingrese su edad: 37
# !Hola Leandro¡, tienes 37 años.

# %%
nombre = input('ingrese su nombre: ')
edad = input('ingrese su edad:')
altura = input(' ingrese su altura')
print(f'!Hola {nombre}¡, tienes {edad} años, y mides {altura} metros.')
# Out:
# ingrese su nombre: Leandro
# ingrese su edad:37
#  ingrese su altura1.70
# !Hola Leandro¡, tienes 37 años, y mides 1.70 metros.

# %% [markdown]
# **Calculando con operadores**

# %%
a = int(input('ingrese un numero:'))
b = int(input('ingrese otro numero:'))
print(a +b)
# Out:
# ingrese un numero:5
# ingrese otro numero:7
# 12

# %%
a = int(input('ingrese un numero: '))
b = int(input('ingrese un numero: '))
c = int(input('ingrese un numero: '))
print(a +b +c )
# Out:
# ingrese un numero: 5
# ingrese un numero: 10
# ingrese un numero: 8
# 23

# %%
p_valor = int(input('ingrese el segundo valor: '))
s_valor = int(input('ingrese el segundo valor: '))
print(p_valor - s_valor)
# Out:
# ingrese el segundo valor: 25
# ingrese el segundo valor: 15
# 10

# %%
a = int(input('ingrese un numero: '))
b = int(input('ingrese otro numero: '))
print(a * b)
# Out:
# ingrese un numero: 25
# ingrese otro numero: 45
# 1125

# %%
numerador = int(input('ingrese el numerador:'))
denominador = int(input('ingrese el denominador:(el numero no puede ser cero)'))
print(numerador / denominador)
# Out:
# ingrese el numerador:16
# ingrese el denominador:(el numero no puede ser cero)3
# 5.333333333333333

# %%
operador = int(input('ingrese un valor: '))
potencia = int(input('ingrese un valor: '))
print(operador**potencia)
# Out:
# ingrese un valor: 7
# ingrese un valor: 9
# 40353607

# %%
numerador = int(input('ingrese el numerador: '))
denominador = int(input('ingrese el denominador: (el denominador no puede ser cero) '))
print( numerador // denominador)
# Out:
# ingrese el numerador: 19
# ingrese el denominador: (el denominador no puede ser cero) 7
# 2

# %%
numerador = int(input('ingrese el numerador: '))
denominador = int(input('ingrese el denominador: (el denominador no puede ser cero)'))
print(numerador % denominador)
# Out:
# ingrese el numerador: 12
# ingrese el denominador: (el denominador no puede ser cero)5
# 2

# %%
nota_a = float(input('ingrese la nota de a: '))
nota_b = float(input('ingrese la nota de b: '))
nota_c = float(input('ingrese la nota de c: '))
print(f'promedio: {(nota_a + nota_b + nota_c)/3}.')
# Out:
# ingrese la nota de a: 9.7
# ingrese la nota de b: 8.6
# ingrese la nota de c: 3.4
# promedio: 7.233333333333332.

# %%
promedio_ponderado = (5*1 +12*2 + 20*3 +5*4) / (1+2+3+4)
print(f'promedio ponderado: {promedio_ponderado}.')
# Out:
# promedio ponderado: 10.9.

# %% [markdown]
# **Editando textos**

# %%
frase = 'El petrerito obliga, escarmienta, ilumina y envalentona, menospreciada no constituye profanación, sino intento de suicidio'
print(frase)
# Out:
# El petrerito obliga, escarmienta, ilumina y envalentona, menospreciada no constituye profanación, sino intento de suicidio

# %%
input('por favor ingrese una frase: ')
# Out:
# por favor ingrese una frase: la suerte esta echada
# 'la suerte esta echada'

# %%
frase  = input('por favor ingrese una frase: ')
frase.upper()
# Out:
# por favor ingrese una frase: la mejor manera de predecir el futuro es crearlo
# 'LA MEJOR MANERA DE PREDECIR EL FUTURO ES CREARLO'

# %%
frase = input(' por favor inrese una frase: ')
frase.lower()
# Out:
#  por favor inrese una frase: SIEMPRE PARECE IMPÓSIBLE HASTA QUE SE HACE
# 'siempre parece impósible hasta que se hace'

# %%
FRASE = '       haz todos los dias algo que te de miedo     '
print(FRASE.strip())
# Out:
# haz todos los dias algo que te de miedo

# %%
frase_ = input('por favor ingrese una frase:')
print(frase_.strip())
# Out:
# por favor ingrese una frase:      la auto educación es la unica forma de crear grandes frotunas
# la auto educación es la unica forma de crear grandes frotunas

# %%
_frase = input('por favor ingrese una frase:')
print(_frase.strip().lower())
# Out:
# por favor ingrese una frase:    LAS PALABRAS GUIAN, EL EJEMPLO ARRASTRA
# las palabras guian, el ejemplo arrastra

# %%
_frase_ = input('por favor ingresa una frase: ')
_frase_.replace('e','f')
# Out:
# por favor ingresa una frase: ser lider es como ser caballero, si tienes que decirlo es por que no lo eres
# 'sfr lidfr fs como sfr caballfro, si tifnfs quf dfcirlo fs por quf no lo frfs '

# %%
Frase = input('por favor ingrese una frase: ')
Frase.replace('a',chr(64))
# Out:
# por favor ingrese una frase: la belleza esta en los ojos del espectador
# 'l@ bellez@ est@ en los ojos del espect@dor'

# %%
_Frase_ = input('por favor ingresa una frase: ')
_Frase_.replace('s',chr(36))
# Out:
# por favor ingresa una frase: los perdedores se rinden cuando fracasan, los ganadores fracasan hasta que consiguen el exito
# 'lo$ perdedore$ $e rinden cuando fraca$an, lo$ ganadore$ fraca$an ha$ta que con$iguen el exito'
