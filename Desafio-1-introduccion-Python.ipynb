# %%
print('Escuela de datos Alura')
# Out:
# Escuela de datos Alura

# %%
print('Nombre:Leandro')
# Out:
# Nombre:Leandro

# %%
print('Apellido:Puebla Martinez')
# Out:
# Apellido:Puebla Martinez

# %%
print('L')
print('E')
print('A')
print('N')
print('D')
print('R')
print('O')
# Out:
# L
# E
# A
# N
# D
# R
# O

# %%
print(1,'noviembre',1987)
# Out:
# 1 noviembre 1987

# %%
print('Año actual:',2025)
# Out:
# Año actual: 2025
