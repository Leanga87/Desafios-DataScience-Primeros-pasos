# %% [markdown]
# ***Vamos practicar el uso de estructuras condicionales como el if, else y elif a través de algunas actividades. Ahora que estamos avanzando en los contenidos, podemos hacer los desafíos más interesantes: ¡trabajaremos en proyectos de código! Resuelve los problemas iniciales para prepararte para los proyectos:***
#
# **Entrenando la programación**
#
# 1 - Escribe un programa que pida a la persona usuaria que proporcione dos números y muestre el número más grande.

# %%
numero_1 = float(input('ingrese el primer valor numerico: '))
numero_2 = float(input('ingrese el segundo valor numerico: '))
if numero_1 > numero_2:
  print(f'El valor ingresado es el mayor: {numero_1} ')
elif numero_2 > numero_1:
  print(f'El valor ingresado es el mayor: {numero_2}')
else:
  print('Los valores ingresados son iguales')
# Out:
# ingrese el primer valor numerico: 5.36
# ingrese el segundo valor numerico: 4.36
# El valor ingresado es el mayor: 5.36

# %% [markdown]
# **2 - Escribe un programa que solicite el porcentaje de crecimiento de producción de una empresa e informe si hubo un crecimiento (porcentaje positivo) o una disminución (porcentaje negativo).**

# %%
variacion = float(input('ingrese el porcentaje de variacion: '))
if variacion > 20:
  print('hubo un crecimiento en la produccion.')
elif variacion < 20:
  print('hubo un decrecimiento en la producción.')
else:
  print('No hubo cambios en la producción.')
# Out:
# ingrese el porcentaje de variacion: 18
# hubo un decrecimiento en la producción.

# %% [markdown]
# **3 - Escribe un programa que determine si una letra proporcionada por la persona usuaria es una vocal o una consonante.**

# %%
letras = input('Ingrese una letra: ').lower()
if letras == 'a' or letras == 'e' or letras == 'i' or letras == 'o' or letras == 'u':
  print('La letra ingresada es una vocal')
else:
  print('La letra ingresada es una consonante')
# Out:
# Ingrese una letra: E
# La letra ingresada es una vocal

# %% [markdown]
# **4 - Escribe un programa que lea valores promedio de precios de un modelo de automóvil durante 3 años consecutivos y muestre el valor más alto y más bajo entre esos tres años.**

# %%
precio_año_1 = float(input('Ingrese el precio del primer año: '))
precio_año_2 = float(input('Ingrese el precio del segundo año: '))
precio_año_3 = float(input('ingrese el precio del tercer año: '))
if precio_año_1 > precio_año_2 and precio_año_1 > precio_año_3:
  print(f'El año con mayor promedio de precio es el primero: {precio_año_1}')
elif precio_año_1 < precio_año_2 and precio_año_2 > precio_año_3:
  print(f'El año con mayor promedio de precio es el segundo: {precio_año_2}')
else:
  print(f'El año con mayor promedio de precio es el tercero: {precio_año_3}')
if precio_año_1 < precio_año_2 and precio_año_1 < precio_año_3:
  print(f'El año con menor promedio de precio es el primero: {precio_año_1}')
elif precio_año_1 > precio_año_2 and precio_año_2 < precio_año_3:
  print(f'El año con menor promedio de precio es el segundo: {precio_año_2}')
else:
  print(f'El año con menor promedio de precio es el tercero: {precio_año_3}')
# Out:
# Ingrese el precio del primer año: 45.36
# Ingrese el precio del segundo año: 39.47
# ingrese el precio del tercer año: 45.69
# El año con mayor promedio de precio es el tercero: 45.69
# El año con menor promedio de precio es el segundo: 39.47

# %% [markdown]
# 5-**Escribe un programa que pregunte sobre el precio de tres productos e indique cuál es el producto más barato para comprar.**

# %%
producto_1 = float(input('Ingrese el precio del primer producto: '))
producto_2 = float(input('Ingrese el precio del segundo producto: '))
producto_3 = float(input('Ingrese el precio del tercer producto: '))
menor_precio = producto_1
if producto_2 < menor_precio:
  menor_precio = producto_2
if producto_3 < menor_precio:
  menor_precio = producto_3
if producto_1 == menor_precio and producto_2 != menor_precio and producto_3 != menor_precio:
  print(f'El producto mas barato es el primero: {producto_1}')
elif producto_2 == menor_precio and producto_1 != menor_precio and producto_3 != menor_precio:
  print(f'El producto mas barato es el segundo: {producto_2}')
elif producto_3 == menor_precio and producto_1 != menor_precio and producto_2 != menor_precio:
  print(f'El producto mas barato es el tercero: {producto_3}')
else:
  print(f'Hay mas de un producto con el precio mas bajo: {menor_precio}')
# Out:
# Ingrese el precio del primer producto: 15.56
# Ingrese el precio del segundo producto: 14.59
# Ingrese el precio del tercer producto: 19.36
# El producto mas barato es el segundo: 14.59

# %% [markdown]
# **6 - Escribe un programa que lea tres números y los muestre en orden descendente.**

# %%
numero_1_ = float(input('Ingrese el primer número: '))
numero_2_ = float(input('Ingrese el segundo número: '))
numero_3_ = float(input('Ingrese el tercer numero: '))
if numero_1_ >= numero_2_ and  numero_2_ >= numero_3_:
  print(numero_1_,numero_2_,numero_3_)
elif numero_1_ >= numero_3_ and numero_3_ >= numero_2_:
  print(numero_1_,numero_3_,numero_2_)
elif numero_2_ >= numero_1_ and numero_1_ >= numero_3_:
  print(numero_2_, numero_1_, numero_3_)
elif numero_2_ >= numero_3_ and numero_3_ >= numero_1_:
  print(numero_2_, numero_1_, numero_3_)
elif numero_3_ >= numero_1_ and numero_1_ >= numero_2_:
  print(numero_3_, numero_1_, numero_2_)
else:
  print(numero_3_, numero_2_, numero_1_)
# Out:
# Ingrese el primer número: 21.6
# Ingrese el segundo número: 25.3
# Ingrese el tercer numero: 29.4
# 29.4 25.3 21.6

# %% [markdown]
# 7 -**Escribe un programa que pregunte en qué turno estudia la persona usuaria ("mañana", "tarde" o "noche") y muestre el mensaje "¡Buenos Días!", "¡Buenas Tardes!", "¡Buenas Noches!" o "Valor Inválido!", según el caso.**

# %%
turno = input('Ingrese el turno que estudia: ').lower()
if turno == 'mañana':
  print('¡Buenos días!')
elif turno == 'tarde':
  print('¡Buenas tardes!')
elif turno == 'noche':
  print('¡Buenas noches!')
else:
  print('¡Valor inválido!')
# Out:
# Ingrese el turno que estudia: TARDES
# valor invalido

# %% [markdown]
# 8 - **Escribe un programa que solicite un número entero a la persona usuaria y determine si es par o impar. Pista: Puedes usar el operador módulo (%).**

# %%
numero_entero = int(input('Ingrese un número entero: '))
if numero_entero % 2 == 0:
  print('El número ingresado es par.')
else:
  print('El número ingresado es impar.')
# Out:
# Ingrese un número entero: 6
# El número ingresado es par.

# %% [markdown]
# 9 - **Escribe un programa que pida un número a la persona usuaria y le informe si es entero o decimal.**

# %%
numero_ = input('Ingrese un número: ')
numero_ = numero_.replace(',','.')
numero_ = float(numero_)
if numero_ % 1== 0.0:
  print('El número ingresado es entero.')
else:
  print('El número ingresado es es decimal.')
# Out:
# Ingrese un número: 4,0
# El número ingresado es entero.

# %% [markdown]
# **Momento de los proyectos**
#
# 10 - ***Un programa debe ser escrito para leer dos números y luego preguntar a la persona usuaria qué operación desea realizar. El resultado de la operación debe incluir información sobre el número, si es par o impar, positivo o negativo, e entero o decimal.***

# %%
Numero_1 = float(input('Ingrese el primer número: '))
Numero_2 = float(input('Ingrese el segundo número: '))
Operacion = input('Ingrese la operación que desea realizar: ').strip().lower()
Resultado = None
if Operacion == '+'or Operacion == 'suma':
  Resultado = Numero_1 + Numero_2
  print(f'El resultado de la suma es : {Resultado}')
elif Operacion == '-'or Operacion == 'resta':
  Resultado = Numero_1 - Numero_2
  print(f'El resultado de la resta es : {Resultado}')
elif Operacion == '*'or Operacion =='multiplicacion':
  Resultado = Numero_1 * Numero_2
  print(f'El resultado de la multiplicación es : {Resultado}')
elif Operacion == '/'or Operacion == 'division':
  if Numero_2 == 0:
    print('No es posible dividir por cero')
  else:
    Resultado = Numero_1 / Numero_2
    print(f'El resultado de la operacion es: {Resultado}')
else:
    print('Operación no válida.')
if Resultado is not None:

 if (Resultado) % 2 == 0:
    print('El resultado es par')
 else:
    print('El resultado es impar')
 if Resultado > 0:
    print('El resultado es positivo')
 elif Resultado < 0:
    print('El resultado es negativo')
 else:
    print('El Resultado es cero')
 if (Resultado) % 1 == 0:
    print('El resultado es entero')
 else:
    print('El resultado es decimal')
# Out:
# Ingrese el primer número: 47
# Ingrese el segundo número: 58
# Ingrese la operación que desea realizar: DIVIDIR
# Operación no válida.

# %% [markdown]
# 11 -**Escribe un programa que pida a la persona usuaria tres números que representan los lados de un triángulo. El programa debe informar si los valores pueden utilizarse para formar un triángulo y, en caso afirmativo, si es equilátero, isósceles o escaleno. Ten en cuenta algunas sugerencias:**
#
# ***Tres lados forman un triángulo cuando la suma de cualesquiera dos lados es mayor que el tercero;
# Triángulo Equilátero: tres lados iguales;
# Triángulo Isósceles: dos lados iguales;
# Triángulo Escaleno: tres lados diferentes.***

# %%
lado_1 = float(input('Ingrese el primer lado del triangulo: '))
lado_2 = float(input('Ingrese el segundo lado del triangulo: '))
lado_3 = float(input('Ingrese el tercer lado del triangulo: '))
if lado_1 <= 0 or lado_2 <= 0 or lado_3 <= 0:
    print('Operacion inválida')
elif lado_1 + lado_2 > lado_3 and lado_1 + lado_3 > lado_2 and lado_2 + lado_3 > lado_1:
  print('Se puede formar un triangulo')
  if lado_1 == lado_2 == lado_3:
   print('El triangulo es equilatero')
  elif lado_1 == lado_2 or lado_1 == lado_3 or lado_2 == lado_3:
   print('El triangulo es isoceles')
  else:
   print('El triangulo es escaleno')
else:
   print('No se puede formar un triangulo')
# Out:
# Ingrese el primer lado del triangulo: 12
# Ingrese el segundo lado del triangulo: 15
# Ingrese el tercer lado del triangulo: 18
# Se puede formar un triangulo
# El triangulo es escaleno

# %% [markdown]
# 12 - **Un establecimiento está vendiendo combustibles con descuentos variables. Para el etanol, si la cantidad comprada es de hasta 15 litros, el descuento será del 2% por litro. En caso contrario, será del 4% por litro. Para el diésel, si la cantidad comprada es de hasta 15 litros, el descuento será del 3% por litro. En caso contrario, será del 5% por litro. El precio por litro de diésel es de  2,00  Reales y el precio por litro de etanol es de 1,70 Reales. Escribe un programa que lea la cantidad de litros vendidos y el tipo de combustible (E para etanol y D para diésel) y calcule el valor a pagar por el cliente. Ten en cuenta algunas sugerencias:**
#
# ***El valor del descuento será el producto del precio por litro, la cantidad de litros y el valor del descuento.
# El valor a pagar por un cliente será el resultado de la multiplicación del precio por litro por la cantidad de litros menos el valor del descuento resultante del cálculo.***

# %%
litros = float(input('Ingrese la cantidad de litros vendidos: '))
tipo_combustible = input('ingrese el tipo de combustible vendido: ').upper()


if tipo_combustible == 'E':
  precio_por_litro = 1.70
  print('El precio por litro de etanol es de 1.70 Reales')

  if litros <= 15:
     descuento = 0.02
  else:
     descuento = 0.04
  total =(precio_por_litro * litros) * (1 - descuento)
  print(f'El valor a pagar por el cliente es : {total:.2f} Reales')

elif tipo_combustible == 'D':
  print('El precio del combustible es de 2.00 Reales')
  precio_por_litro = 2.00
  if litros <= 15:
     descuento = 0.03
  else:
     descuento = 0.05
  total = (precio_por_litro * litros) * (1 - descuento)
  print(f'El valor a pagar por el cliente es: {total:.2f} Reales')

else:
   print('Tipo de combustible inválido. use E para etanol y D para Diesél')
# Out:
# Ingrese la cantidad de litros vendidos: 14
# ingrese el tipo de combustible vendido: d
# El precio del combustible es de 2.00 Reales
# El valor a pagar por el cliente es: 27.16 Reales

# %% [markdown]
# 13 - **En una empresa de venta de bienes raíces, debes crear un código que analice los datos de ventas anuales para ayudar a la dirección en la toma de decisiones.
# El código debe recopilar los datos de cantidad de ventas durante los años 2022 y 2023 y calcular la variación porcentual.
# A partir del valor de la variación, se deben proporcionar las siguientes sugerencias:**
#
# ***Para una variación superior al 20%: bonificación para el equipo de ventas.
# Para una variación entre el 2% y el 20%: pequeña bonificación para el equipo de ventas.
# Para una variación entre el 2% y el -10%: planificación de políticas de incentivo a las ventas.
# Para bonificaciones inferiores al -10%: recorte de gastos.***

# %%
ventas_2022 = float(input('Ingrese la cantidad de ventas del año 2022: '))
ventas_2023 = float(input('Ingrese la cantidad de ventas del año 2023: '))
variacion = ((ventas_2023 - ventas_2022) / ventas_2022) *100
print(f'La variacion porcentual de ventas fue de {variacion:.2f}%')
if variacion > 20:
  print('Bonificacion para el equipo de ventas')
elif variacion >= 2 and variacion <= 20:
  print('Pequeña bonificacion para el equipo de ventas')
elif variacion >= -10 and variacion < 2:
  print('planificacion de politicas de incentivo a las ventas')
else:
  print('Recorte de gastos')
# Out:
# Ingrese la cantidad de ventas del año 2022: 40
# Ingrese la cantidad de ventas del año 2023: 45
# La variacion porcentual de ventas fue de 12.50%
# Pequeña bonificacion para el equipo de ventas
